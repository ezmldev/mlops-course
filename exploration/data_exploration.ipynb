# %%
import logging
import pandas as pd

logging.root.setLevel(logging.INFO)
pd.set_option('display.max_colwidth', None)

# %%
"""
Dataset: http://archive.ics.uci.edu/dataset/380/youtube+spam+collection
"""

from pathlib import Path
import pandas as pd

data_files_dir = Path.cwd().parent / "data"

if not data_files_dir.exists():
    logging.error(f"Data files directory {data_files_dir} does not exist")
    raise SystemExit(1)

df = pd.read_csv(data_files_dir / "comments.csv")
df.head(100)
# Out:
#                                                                          content  \
# 0                                                            Best Music Ever!!!﻿
# 1   please look up DHG SONGS this is my playlist with a bunch of amazing songs ﻿
# 2                                                             just :( superr!!!﻿
# 3                                           Check out this playlist on YouTube:﻿
# 4                 subscribed :) btw you have a good style keep it up brother :))
# ..                                                                           ...
# 95                                     Subscribe &amp; Like /watch?v=5tu9gN1l310
# 96                                :) I&#39;ll subscribe to you. You look Nice :)
# 97                                      subcribe to us an we will subscribe back
# 98                  I made a gaming channel (Unique right?) :L Angry Minecraft!﻿
# 99                                                         Love this song !!!!!!
#
#     is_spam
# 0         0
# 1         1
# 2         0
# 3         1
# 4         1
# ..      ...
# 95        1
# 96        1
# 97        1
# 98        1
# 99        0
#
# [100 rows x 2 columns]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def draw_wordcloud(df):
    all_text = ' '.join(df['content'])
    
    wordcloud = WordCloud(width=800, height=400, background_color='white', random_state=42).generate(all_text)
    
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

draw_wordcloud(df)

# %%
draw_wordcloud(df[ df["is_spam"] == 0 ])

# %%
draw_wordcloud(df[ df["is_spam"] == 1 ])
